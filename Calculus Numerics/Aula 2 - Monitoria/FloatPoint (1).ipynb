# %%
N = 29

k = 0
denominador = 2
quociente = N//denominador
resto = N%denominador
d = []
d.append(resto)

while quociente != 0:
  k = k + 1
  N = quociente
  quociente = N//denominador
  resto = N%denominador
  d.append(resto)
else:
  print("fim")

print(d[::-1])
# Out:
# fim
# [1, 1, 1, 0, 1]
